# %%
L=[1,4,7,9]
L_sum=sum(L)
count=(L)
print(L_sum)
len(L)
# Out:
# 21
# 4

# %%
J=[14,42,17,19]
k=sum(J)
print(k)
count=len(J)
print(count)
# Out:
# 92
# 4

# %%
p=[23,73,56,28,19,18,17,34,71]
x=sum(p)
y=len(p)
print(x)
print(y)
z=x/y
print("mean:",z)
# Out:
# 339
# 9
# mean: 37.666666666666664

# %%
z=[24,19,18,17,34,71]
x=sum(z)
y=len(z)
print(x)
print(y)
z=x/y
print("mean:",z)
# Out:
# 183
# 6
# mean: 30.5

# %%
S=[3,6,4,8]
y=sum(S)
x=len(S)
z=y/x
print(z)
# Out:
# 5.25

# %%
f=[13,63,42,81]
r=sum(f)
y=len(f)
z=r/y
print(r)
print(y)
print(z)
# Out:
# 199
# 4
# 49.75
