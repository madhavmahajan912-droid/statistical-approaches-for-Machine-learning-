# %%
k=[2,4,5,6,8,9,12,14,15,17,19]
print(k[0])
print(k[1])
print(k[2])
print(k[3])
print(k[4])
print(k[5])
print(k[6])
print(k[7])
print(k[8])
print(k[9])
print(k[10])
# Out:
# 2
# 4
# 5
# 6
# 8
# 9
# 12
# 14
# 15
# 17
# 19

# %%
k=[2,4,5,6,8,9,12,14,15,17,19]
n=len(k)
midpose=n//2 
print('mid_position:',midpose)
# Out:
# mid_position: 5

# %%
print(k[midpose])
# Out:
# 9

# %%
k= [12, 14, 15, 16, 18, 19, 22, 24, 25, 27, 29, 39, 40, 42, 45, 47, 49]
print(k[:16])
# Out:
# [12, 14, 15, 16, 18, 19, 22, 24, 25, 27, 29, 39, 40, 42, 45, 47]

# %%
n=len(k)
midpose=n//2
print('midpose :',midpose)
print(k[midpose])
# Out:
# midpose : 8
# 25

# %%
M=[12,14,15]
print(M[:3])
n=len(M)
midpose=n//2
print("midpose :",midpose)
print(M[midpose])
# Out:
# [12, 14, 15]
# midpose : 1
# 14

# %%
N=[12, 14,15, 16, 17]
print(N[:5])
n=len(N)
midpose=n//2 
print('midpose :',midpose)
print(N[midpose])
# Out:
# [12, 14, 15, 16, 17]
# midpose : 2
# 15

# %%
#even 
p = [12, 14, 15, 16]
#A
print(p[0:])
#B
n=len(p)
midpose1, midpose2 = n//2, n//2-1
print(midpose1, midpose2)
#C
print(p[midpose1], p[midpose2])
# Out:
# [12, 14, 15, 16]
# 2 1
# 15 14

# %%
Q=[12, 14, 15, 16, 18, 19]
#A
print(Q[0:])
#B
n=len(Q)
midpose1, midpose2 = n//2-1, n//2
print("midpose :" , midpose1, midpose2)
#C
print( "midpose value :", Q[midpose1],Q[midpose2])
# Out:
# [12, 14, 15, 16, 18, 19]
# midpose : 2 3
# midpose value : 15 16

# %%
R = [12, 14, 15, 16, 18, 19, 20, 22]
#A
print(R[0:])
#B
n=len(R)
midpose1, midpose2 = n//2-1, n//2
print("midpose :" , midpose1, midpose2)
#C
print( "midpose value :", R[midpose1],R[midpose2])
# Out:
# [12, 14, 15, 16, 18, 19, 20, 22]
# midpose : 3 4
# midpose value : 16 18

# %%
S = [12, 14, 15, 16, 18, 19, 20, 22, 24, 27]
#A
print(S[0:])
#B
n=len(R)
midpose1, midpose2 = n//2-1, n//2
print("midpose :" , midpose1, midpose2)
#C
print( "midpose value :", S[midpose1],S[midpose2])
# Out:
# [12, 14, 15, 16, 18, 19, 20, 22, 24, 27]
# midpose : 3 4
# midpose value : 16 18
